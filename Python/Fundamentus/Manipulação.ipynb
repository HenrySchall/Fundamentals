# %% [markdown]
# ## Operadores Lógicos
# Além das operações matemáticas, Python permite operações lógicas:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Resumo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
